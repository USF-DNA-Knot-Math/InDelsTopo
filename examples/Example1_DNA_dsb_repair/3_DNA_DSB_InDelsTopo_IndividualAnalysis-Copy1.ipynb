# %% [markdown]
# # 3. DNA-DSB InDelsTopo Replicate Analysis
#
# In this notebook we analyze DNA double-strand break (DSB) repair data from [Jeon et al.](https://www.nature.com/articles/s41467-024-51457-9) using the **Insertion Chain Complex**, implemented in the package **InDelsTopo**. We work with the averaged data from four biological replicates per experimental condition, preprocessed in `1_Preprocess_Data.ipynb`.
#
# In the underlying experiments, DSBs are introduced at prescribed positions along a DNA molecule (A, B, AB, or C/D), together with additional experimental modifiers such as RNA orientation (sense/antisense), cellular background (WT/KO), RNase context (R1/R2), RNA structure (branch or branchΔ), and transcriptional activity (presence or absence of a CMV promoter). After repair, DNA sequences are obtained by high-throughput sequencing and aligned to the original reference sequence.
#
# The input data analyzed here consists of frequency tables of repaired DNA sequences (`window_freq_withoutSubst.tsv`), generated using the pipeline of [Channagiri et al.](https://github.com/tchannagiri/DSBplot) and reproduced in the repository of [Jeon et al.](https://github.com/xph9876/RNA-mediated_DSB_repair/). From these data, we isolate the DNA subsequences inserted at the repair site and, for each experimental design, and retain only sequences with a
# frequency of at least $10^{-5}$.

# %%
import pandas as pd
pd.options.display.float_format = '{:.2e}'.format
import numpy as np
import pickle as pkl
import matplotlib.pyplot as plt
import networkx as nx

from utils.utils import *

from InDelsTopo import Filtration

with open('data/preprocessed/Human_experiments_all.pickle', 'rb') as handle:
    All_Experiments = pkl.load(handle)

# %% [markdown]
# ## A. Computing Filtrations and Topological Signatures
#
# We begin by loading the preprocessed data from
# `data/preprocessed/Human_experiments_all.pickle`.
#
# For each experiment, we retain only insertion subsequences with a frequency of at least $10^{-5}$ and normalize the remaining frequencies so that they sum to 1. Using these normalized distributions, we construct a **filtration of insertion chain complexes** with the `Filtration` object from **InDelsTopo**, up to dimension `max_dim = 10`. The experimental condition associated with each filtration is stored as the attribute `K.exp_name`.
#
# As a topological signature, we compute a **logarithmic Euler characteristic curve** for each filtration. Specifically, we sample `sample_n` values logarithmically in the interval $[10^{-7}, 1]$ and evaluate the Euler characteristic of the filtration at each sampled value. These curves are stored as rows of the data matrix $X$.

# %%
sample_n=50
min_threshold=1e-5
max_dim=10

#x-coordinates for computing Euler Curves
xs=np.power(10,np.linspace(-7,0,num=sample_n))

#Create matrix to save Euler Curves, and lists to sava labels and complexes
X=np.zeros((len(All_Experiments),sample_n))
labels=[]
Filtrations=[]

#Create Complexes and save them
id_exp=0
for Experiment in All_Experiments:
    exp_name=Experiment['exp_name']
    labels.append(exp_name)
    Table=Experiment['table'].sort_values('freq',ascending=True)

    #Filter by threshold for average frequency
    Table=Table[Table.freq>=min_threshold]

    Words=list(Table.sequence)
    Freqs=np.array(Table.freq)

    #normalize Freqs
    Freqs=Freqs/sum(Freqs)

    #Create Filtration
    K=Filtration()
    K.exp_name=exp_name
    K.compute_d_skeleton(Words,Freqs,max_dim)
    Filtrations.append(K)

    xs,ys=K.get_euler_curve(xs)

    X[id_exp]=ys
    id_exp+=1
# Out:
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)
# Product symbol set to (concatenation)

# %% [markdown]
# ## B. Hierarchical Clustering and Projection
#
# We perform hierarchical clustering using `AgglomerativeClustering` from `sklearn` with `average` linkage. The resulting hierarchy is visualized as a dendrogram, where each leaf corresponds to an average experiment and is labeled by its experimental design.
#
# The clustering shows an almost clean separation by **DSB break location** (A, B, AB, and C/D). To highlight this structure, experiments are colored according to their break location.
#
# We also visualize the data in two dimensions using **t-SNE**. In the projected space, averaged experiments are again colored by break site, and a clear clustering by break location is observed.
#
# ### Conclusion
#
# These results provide further evidence that DNA repair outcomes are influenced by the **local DNA sequence at the break site**. In particular, the topological signatures derived from collections of insertion subsequences cluster according to break position.

# %%
from sklearn.cluster import AgglomerativeClustering
from sklearn.manifold import TSNE

#Compute clustering and plot
model = AgglomerativeClustering(distance_threshold=0, n_clusters=None,linkage='average')
model = model.fit(X)

plt.figure(figsize=(3,40))
plt.title("Hierarchical Clustering Dendrogram (Average Human Cells)")
plot_dendrogram(model, truncate_mode="level",labels=labels,
                leaf_font_size=10)
plt.show()

tSNE=TSNE(metric='euclidean',perplexity=10,n_components=2,random_state=42)
Y=tSNE.fit_transform(X)

plot_projection(Y,labels, figsize=(5,5))
plt.title("TSNE Projection (Individual Human Cells)")
plt.show()

# %% [markdown]
# ## C. Betti Numbers
#
# We computed the homology of the Insertion Chain Complexes for the experiments (at frequency = 1) and report both their Betti numbers and the dimensions of the complexes. We observe:
#
# 1. The dimensions of the resulting complexes range from 2 to 4.
# 2. Most complexes have more than one connected component ($B_0 > 1$). This is likely due to noise, as random sequences that do not connect to any other sequences contribute no information about the underlying structure.
# 3. All but three experiments exhibit no higher-dimensional homology. In the exceptions, only one single 1-dimensional cycle is observed.
#
# ### Conclusions
#
# The minimal dimension of 2 supports our approach of generalizing the Insertion Graph to a higher-dimensional object.
#
# Theorem 5.12 from (Jonoska, Martinez-Figueroa, Saito) [https://arxiv.org/abs/2509.12607] implies that if we observe most intermediate subsequences between the empty sequence (perfect repair) and the maximal inserted subsequences then all homology should vanish. This is what we expect if insertions occur randomly without bias. Since higher-dimensional homology largely vanishes for our experiments, this provides evidence that insertions are occurring in an unbiased manner.

# %%
#Finally we compute the betti numbers of these Complexes
Table=[]
for label, K in zip(labels,Filtrations):
    betti_numbers=K.get_complex().get_betti_numbers_z2()
    Table.append([label, K.dim]+[safe_get(betti_numbers,i) for i in range(5)])

Table=pd.DataFrame(Table)
Table.columns = ['Experiment', 'Dimension','β₀', 'β₁','β₂', 'β₃','β₄']

#We format the table
format_table(Table)
# Out:
# <style type="text/css">
# #T_88b1d_row0_col0, #T_88b1d_row1_col0, #T_88b1d_row2_col0, #T_88b1d_row3_col0, #T_88b1d_row4_col0, #T_88b1d_row5_col0, #T_88b1d_row6_col0, #T_88b1d_row7_col0, #T_88b1d_row8_col0, #T_88b1d_row9_col0, #T_88b1d_row10_col0, #T_88b1d_row11_col0, #T_88b1d_row12_col0, #T_88b1d_row13_col0, #T_88b1d_row14_col0, #T_88b1d_row15_col0, #T_88b1d_row16_col0, #T_88b1d_row17_col0, #T_88b1d_row18_col0, #T_88b1d_row19_col0, #T_88b1d_row20_col0, #T_88b1d_row21_col0, #T_88b1d_row22_col0, #T_88b1d_row23_col0, #T_88b1d_row48_col0, #T_88b1d_row49_col0, #T_88b1d_row50_col0, #T_88b1d_row51_col0, #T_88b1d_row52_col0, #T_88b1d_row53_col0, #T_88b1d_row54_col0, #T_88b1d_row55_col0, #T_88b1d_row56_col0, #T_88b1d_row57_col0, #T_88b1d_row58_col0, #T_88b1d_row59_col0, #T_88b1d_row60_col0, #T_88b1d_row61_col0, #T_88b1d_row62_col0, #T_88b1d_row63_col0, #T_88b1d_row64_col0, #T_88b1d_row65_col0, #T_88b1d_row66_col0, #T_88b1d_row67_col0, #T_88b1d_row68_col0, #T_88b1d_row69_col0, #T_88b1d_row70_col0, #T_88b1d_row71_col0 {
#   color: red;
# }
# #T_88b1d_row24_col0, #T_88b1d_row25_col0, #T_88b1d_row26_col0, #T_88b1d_row27_col0, #T_88b1d_row28_col0, #T_88b1d_row29_col0, #T_88b1d_row30_col0, #T_88b1d_row31_col0, #T_88b1d_row32_col0, #T_88b1d_row33_col0, #T_88b1d_row34_col0, #T_88b1d_row35_col0, #T_88b1d_row72_col0, #T_88b1d_row73_col0, #T_88b1d_row74_col0, #T_88b1d_row75_col0, #T_88b1d_row76_col0, #T_88b1d_row77_col0, #T_88b1d_row78_col0, #T_88b1d_row79_col0, #T_88b1d_row80_col0, #T_88b1d_row81_col0, #T_88b1d_row82_col0, #T_88b1d_row83_col0 {
#   color: green;
# }
# #T_88b1d_row36_col0, #T_88b1d_row37_col0, #T_88b1d_row38_col0, #T_88b1d_row39_col0, #T_88b1d_row40_col0, #T_88b1d_row41_col0, #T_88b1d_row42_col0, #T_88b1d_row43_col0, #T_88b1d_row44_col0, #T_88b1d_row45_col0, #T_88b1d_row46_col0, #T_88b1d_row47_col0, #T_88b1d_row84_col0, #T_88b1d_row85_col0, #T_88b1d_row86_col0, #T_88b1d_row87_col0, #T_88b1d_row88_col0, #T_88b1d_row89_col0, #T_88b1d_row90_col0, #T_88b1d_row91_col0, #T_88b1d_row92_col0, #T_88b1d_row93_col0, #T_88b1d_row94_col0, #T_88b1d_row95_col0 {
#   color: blue;
# }
# #T_88b1d_row96_col0, #T_88b1d_row97_col0, #T_88b1d_row98_col0, #T_88b1d_row99_col0, #T_88b1d_row100_col0, #T_88b1d_row101_col0, #T_88b1d_row102_col0, #T_88b1d_row103_col0, #T_88b1d_row104_col0, #T_88b1d_row105_col0, #T_88b1d_row106_col0, #T_88b1d_row107_col0, #T_88b1d_row108_col0, #T_88b1d_row109_col0, #T_88b1d_row110_col0, #T_88b1d_row111_col0 {
#   color: orange;
# }
# </style>
# <table id="T_88b1d">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_88b1d_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_88b1d_level0_col1" class="col_heading level0 col1" >Dimension</th>
#       <th id="T_88b1d_level0_col2" class="col_heading level0 col2" >β₀</th>
#       <th id="T_88b1d_level0_col3" class="col_heading level0 col3" >β₁</th>
#       <th id="T_88b1d_level0_col4" class="col_heading level0 col4" >β₂</th>
#       <th id="T_88b1d_level0_col5" class="col_heading level0 col5" >β₃</th>
#       <th id="T_88b1d_level0_col6" class="col_heading level0 col6" >β₄</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_88b1d_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_88b1d_row0_col0" class="data row0 col0" >KO_sgAB_R1_branch_yjl233</td>
#       <td id="T_88b1d_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_88b1d_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_88b1d_row0_col3" class="data row0 col3" ></td>
#       <td id="T_88b1d_row0_col4" class="data row0 col4" ></td>
#       <td id="T_88b1d_row0_col5" class="data row0 col5" ></td>
#       <td id="T_88b1d_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_88b1d_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_88b1d_row1_col0" class="data row1 col0" >KO_sgAB_R1_branch_yjl234</td>
#       <td id="T_88b1d_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_88b1d_row1_col2" class="data row1 col2" >2</td>
#       <td id="T_88b1d_row1_col3" class="data row1 col3" ></td>
#       <td id="T_88b1d_row1_col4" class="data row1 col4" ></td>
#       <td id="T_88b1d_row1_col5" class="data row1 col5" ></td>
#       <td id="T_88b1d_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_88b1d_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_88b1d_row2_col0" class="data row2 col0" >KO_sgAB_R1_branch_yjl235</td>
#       <td id="T_88b1d_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_88b1d_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_88b1d_row2_col3" class="data row2 col3" ></td>
#       <td id="T_88b1d_row2_col4" class="data row2 col4" ></td>
#       <td id="T_88b1d_row2_col5" class="data row2 col5" ></td>
#       <td id="T_88b1d_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_88b1d_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_88b1d_row3_col0" class="data row3 col0" >KO_sgAB_R1_branch_yjl236</td>
#       <td id="T_88b1d_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_88b1d_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_88b1d_row3_col3" class="data row3 col3" ></td>
#       <td id="T_88b1d_row3_col4" class="data row3 col4" ></td>
#       <td id="T_88b1d_row3_col5" class="data row3 col5" ></td>
#       <td id="T_88b1d_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_88b1d_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_88b1d_row4_col0" class="data row4 col0" >KO_sgAB_R1_cmv_yjl237</td>
#       <td id="T_88b1d_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_88b1d_row4_col2" class="data row4 col2" >3</td>
#       <td id="T_88b1d_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_88b1d_row4_col4" class="data row4 col4" ></td>
#       <td id="T_88b1d_row4_col5" class="data row4 col5" ></td>
#       <td id="T_88b1d_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_88b1d_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_88b1d_row5_col0" class="data row5 col0" >KO_sgAB_R1_cmv_yjl238</td>
#       <td id="T_88b1d_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_88b1d_row5_col2" class="data row5 col2" >4</td>
#       <td id="T_88b1d_row5_col3" class="data row5 col3" ></td>
#       <td id="T_88b1d_row5_col4" class="data row5 col4" ></td>
#       <td id="T_88b1d_row5_col5" class="data row5 col5" ></td>
#       <td id="T_88b1d_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_88b1d_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_88b1d_row6_col0" class="data row6 col0" >KO_sgAB_R1_cmv_yjl239</td>
#       <td id="T_88b1d_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_88b1d_row6_col2" class="data row6 col2" >2</td>
#       <td id="T_88b1d_row6_col3" class="data row6 col3" ></td>
#       <td id="T_88b1d_row6_col4" class="data row6 col4" ></td>
#       <td id="T_88b1d_row6_col5" class="data row6 col5" ></td>
#       <td id="T_88b1d_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_88b1d_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_88b1d_row7_col0" class="data row7 col0" >KO_sgAB_R1_cmv_yjl240</td>
#       <td id="T_88b1d_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_88b1d_row7_col2" class="data row7 col2" >3</td>
#       <td id="T_88b1d_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_88b1d_row7_col4" class="data row7 col4" ></td>
#       <td id="T_88b1d_row7_col5" class="data row7 col5" ></td>
#       <td id="T_88b1d_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_88b1d_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_88b1d_row8_col0" class="data row8 col0" >KO_sgAB_R1_sense_yjl229</td>
#       <td id="T_88b1d_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_88b1d_row8_col2" class="data row8 col2" >4</td>
#       <td id="T_88b1d_row8_col3" class="data row8 col3" ></td>
#       <td id="T_88b1d_row8_col4" class

# %% [markdown]
# ### D. Understanding the Connected Components
#
# The presence of multiple connected components does not necessarily contradict our hypothesis that insertions occur largely at random and without bias. Even in a completely random process, some sequences may appear in isolation and therefore form small disconnected components.
#
# Occasionally, larger disconnected components may also appear. While these do not necessarily indicate a systematic bias in the insertion process, they can still be informative. In particular, it is interesting to observe whether such components arise consistently across experiments of the same type, as this may point to features of the experimental setup or sampling process rather than the underlying insertion mechanism.
#
# We compute the total weight and size of the (up to) first five connected components. Notably, most second components with more than two elements appear in experiments **KO_sgaAB_R1** and **WT_sgAB_R1**, which are also the experiments where 1-dimensional cycles are observed. However, when the threshold is lowered from $10^{-5}$ to $10^{-6}$, these larger second components merge with the first component, leaving only small disconnected components. This indicates that, while this behavior may be observed in certain types of experiments, it does not provide sufficient evidence to conclude that the insertion process is non-random or biased.

# %%
#Auxiliary Methods
def one_skeleton_threshold(Table_exp, threshold):
    '''Produce the 1-skeleton of the corresponding experiment at the provided threshold'''
    Table_exp=Table_exp.sort_values('freq',ascending=True)

    #Filter by threshold for average frequency
    Table_exp=Table_exp[Table_exp.freq>=threshold]

    K=Filtration()
    K.compute_d_skeleton(list(Table_exp.sequence), list(Table_exp.freq),
                         max_dim=1, prod_symbol='')

    graph=create_nx_graph(K)

    return graph, K

def create_table_components(threshold):
    Table_components=[]
    for Experiment in All_Experiments:
        graph_exp, K=one_skeleton_threshold(Experiment['table'], threshold)

        #Compute components
        components = list(nx.connected_components(graph_exp))
        components.sort(key=len,reverse=True)
        component_weights=[sum([K[0][v] for v in C]) for C in components]
        weights_table=component_weights+[0,0,0,0,0]
        weights_table=weights_table[0:5]
        
        component_sizes=[len(C) for C in components]
        sizes_table=component_sizes+[0,0,0,0,0]
        sizes_table=sizes_table[0:5]

        Table_components.append([Experiment['exp_name']]+\
                      [x for pair in zip(weights_table, sizes_table) for x in pair])

    Table_components=pd.DataFrame(Table_components)
    Table_components.columns = ['Experiment','W₀','C₀', 'W₁','C₁','W₂','C₂', 'W₃','C₃', 'W₄','C₄']

    return Table_components

# %%
c_cols=['C₀','C₁','C₂','C₃','C₄']

Table_components=create_table_components(1e-5)

#Examining the experiments with large second component
large_second_component=Table_components['Experiment'][Table_components['C₁']>3]
Table_components=Table_components[Table_components['Experiment'].isin(large_second_component)]

print('Conected components size and weight for threshold 1e-5, if second component has at least 3 elements')
format_table(Table_components,gray_cols=c_cols)

#Examining the experiments with large second component, at a lower threshold

Table_components2=create_table_components(1e-6)
Table_components2=Table_components2[Table_components2['Experiment'].isin(large_second_component)]

print('Experiments with large second component, at a lower threshold of 1e-6')
format_table(Table_components2,gray_cols=c_cols)
# Out:
# Conected components size and weight for threshold 1e-5, if second component has at least 3 elements
# <style type="text/css">
# #T_0ea7c_row0_col0, #T_0ea7c_row1_col0, #T_0ea7c_row2_col0, #T_0ea7c_row3_col0, #T_0ea7c_row4_col0, #T_0ea7c_row5_col0, #T_0ea7c_row6_col0, #T_0ea7c_row7_col0, #T_0ea7c_row8_col0, #T_0ea7c_row9_col0, #T_0ea7c_row10_col0, #T_0ea7c_row11_col0, #T_0ea7c_row12_col0, #T_0ea7c_row13_col0, #T_0ea7c_row14_col0, #T_0ea7c_row15_col0, #T_0ea7c_row16_col0 {
#   color: red;
# }
# #T_0ea7c_row0_col2, #T_0ea7c_row0_col4, #T_0ea7c_row0_col6, #T_0ea7c_row0_col8, #T_0ea7c_row0_col10, #T_0ea7c_row1_col2, #T_0ea7c_row1_col4, #T_0ea7c_row1_col6, #T_0ea7c_row1_col8, #T_0ea7c_row1_col10, #T_0ea7c_row2_col2, #T_0ea7c_row2_col4, #T_0ea7c_row2_col6, #T_0ea7c_row2_col8, #T_0ea7c_row2_col10, #T_0ea7c_row3_col2, #T_0ea7c_row3_col4, #T_0ea7c_row3_col6, #T_0ea7c_row3_col8, #T_0ea7c_row3_col10, #T_0ea7c_row4_col2, #T_0ea7c_row4_col4, #T_0ea7c_row4_col6, #T_0ea7c_row4_col8, #T_0ea7c_row4_col10, #T_0ea7c_row5_col2, #T_0ea7c_row5_col4, #T_0ea7c_row5_col6, #T_0ea7c_row5_col8, #T_0ea7c_row5_col10, #T_0ea7c_row6_col2, #T_0ea7c_row6_col4, #T_0ea7c_row6_col6, #T_0ea7c_row6_col8, #T_0ea7c_row6_col10, #T_0ea7c_row7_col2, #T_0ea7c_row7_col4, #T_0ea7c_row7_col6, #T_0ea7c_row7_col8, #T_0ea7c_row7_col10, #T_0ea7c_row8_col2, #T_0ea7c_row8_col4, #T_0ea7c_row8_col6, #T_0ea7c_row8_col8, #T_0ea7c_row8_col10, #T_0ea7c_row9_col2, #T_0ea7c_row9_col4, #T_0ea7c_row9_col6, #T_0ea7c_row9_col8, #T_0ea7c_row9_col10, #T_0ea7c_row10_col2, #T_0ea7c_row10_col4, #T_0ea7c_row10_col6, #T_0ea7c_row10_col8, #T_0ea7c_row10_col10, #T_0ea7c_row11_col2, #T_0ea7c_row11_col4, #T_0ea7c_row11_col6, #T_0ea7c_row11_col8, #T_0ea7c_row11_col10, #T_0ea7c_row12_col2, #T_0ea7c_row12_col4, #T_0ea7c_row12_col6, #T_0ea7c_row12_col8, #T_0ea7c_row12_col10, #T_0ea7c_row13_col2, #T_0ea7c_row13_col4, #T_0ea7c_row13_col6, #T_0ea7c_row13_col8, #T_0ea7c_row13_col10, #T_0ea7c_row14_col2, #T_0ea7c_row14_col4, #T_0ea7c_row14_col6, #T_0ea7c_row14_col8, #T_0ea7c_row14_col10, #T_0ea7c_row15_col2, #T_0ea7c_row15_col4, #T_0ea7c_row15_col6, #T_0ea7c_row15_col8, #T_0ea7c_row15_col10, #T_0ea7c_row16_col2, #T_0ea7c_row16_col4, #T_0ea7c_row16_col6, #T_0ea7c_row16_col8, #T_0ea7c_row16_col10, #T_0ea7c_row17_col2, #T_0ea7c_row17_col4, #T_0ea7c_row17_col6, #T_0ea7c_row17_col8, #T_0ea7c_row17_col10, #T_0ea7c_row18_col2, #T_0ea7c_row18_col4, #T_0ea7c_row18_col6, #T_0ea7c_row18_col8, #T_0ea7c_row18_col10 {
#   color: gray;
# }
# #T_0ea7c_row17_col0, #T_0ea7c_row18_col0 {
#   color: orange;
# }
# </style>
# <table id="T_0ea7c">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_0ea7c_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_0ea7c_level0_col1" class="col_heading level0 col1" >W₀</th>
#       <th id="T_0ea7c_level0_col2" class="col_heading level0 col2" >C₀</th>
#       <th id="T_0ea7c_level0_col3" class="col_heading level0 col3" >W₁</th>
#       <th id="T_0ea7c_level0_col4" class="col_heading level0 col4" >C₁</th>
#       <th id="T_0ea7c_level0_col5" class="col_heading level0 col5" >W₂</th>
#       <th id="T_0ea7c_level0_col6" class="col_heading level0 col6" >C₂</th>
#       <th id="T_0ea7c_level0_col7" class="col_heading level0 col7" >W₃</th>
#       <th id="T_0ea7c_level0_col8" class="col_heading level0 col8" >C₃</th>
#       <th id="T_0ea7c_level0_col9" class="col_heading level0 col9" >W₄</th>
#       <th id="T_0ea7c_level0_col10" class="col_heading level0 col10" >C₄</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_0ea7c_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_0ea7c_row0_col0" class="data row0 col0" >KO_sgAB_R1_branch_yjl236</td>
#       <td id="T_0ea7c_row0_col1" class="data row0 col1" >$1.28 \times 10^{-1}$</td>
#       <td id="T_0ea7c_row0_col2" class="data row0 col2" >22</td>
#       <td id="T_0ea7c_row0_col3" class="data row0 col3" >$1.13 \times 10^{-4}$</td>
#       <td id="T_0ea7c_row0_col4" class="data row0 col4" >4</td>
#       <td id="T_0ea7c_row0_col5" class="data row0 col5" ></td>
#       <td id="T_0ea7c_row0_col6" class="data row0 col6" ></td>
#       <td id="T_0ea7c_row0_col7" class="data row0 col7" ></td>
#       <td id="T_0ea7c_row0_col8" class="data row0 col8" ></td>
#       <td id="T_0ea7c_row0_col9" class="data row0 col9" ></td>
#       <td id="T_0ea7c_row0_col10" class="data row0 col10" ></td>
#     </tr>
#     <tr>
#       <th id="T_0ea7c_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_0ea7c_row1_col0" class="data row1 col0" >KO_sgAB_R1_cmv_yjl238</td>
#       <td id="T_0ea7c_row1_col1" class="data row1 col1" >$3.48 \times 10^{-1}$</td>
#       <td id="T_0ea7c_row1_col2" class="data row1 col2" >31</td>
#       <td id="T_0ea7c_row1_col3" class="data row1 col3" >$3.71 \times 10^{-4}$</td>
#       <td id="T_0ea7c_row1_col4" class="data row1 col4" >6</td>
#       <td id="T_0ea7c_row1_col5" class="data row1 col5" >$1.04 \times 10^{-5}$</td>
#       <td id="T_0ea7c_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_0ea7c_row1_col7" class="data row1 col7" >$1.41 \times 10^{-5}$</td>
#       <td id="T_0ea7c_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_0ea7c_row1_col9" class="data row1 col9" ></td>
#       <td id="T_0ea7c_row1_col10" class="data row1 col10" ></td>
#     </tr>
#     <tr>
#       <th id="T_0ea7c_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_0ea7c_row2_col0" class="data row2 col0" >KO_sgAB_R1_cmv_yjl239</td>
#       <td id="T_0ea7c_row2_col1" class="data row2 col1" >$3.39 \times 10^{-1}$</td>
#       <td id="T_0ea7c_row2_col2" class="data row2 col2" >29</td>
#       <td id="T_0ea7c_row2_col3" class="data row2 col3" >$4.27 \times 10^{-4}$</td>
#       <td id="T_0ea7c_row2_col4" class="data row2 col4" >9</td>
#       <td id="T_0ea7c_row2_col5" class="data row2 col5" ></td>
#       <td id="T_0ea7c_row2_col6" class="data row2 col6" ></td>
#       <td id="T_0ea7c_row2_col7" class="data row2 col7" ></td>
#       <td id="T_0ea7c_row2_col8" class="data row2 col8" ></td>
#       <td id="T_0ea7c_row2_col9" class="data row2 col9" ></td>
#       <td id="T_0ea7c_row2_col10" class="data row2 col10" ></td>
#     </tr>
#     <tr>
#       <th id="T_0ea7c_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_0ea7c_row3_col0" class="data row3 col0" >KO_sgAB_R1_cmv_yjl240</td>
#       <td id="T_0ea7c_row3_col1" class="data row3 col1" >$3.16 \times 10^{-1}$</td>
#       <td id="T_0ea7c_row3_col2" class="data row3 col2" >30</td>
#       <td id="T_0ea7c_row3_col3" class="data row3 col3" >$4.13 \times 10^{-4}$</td>
#       <td id="T_0ea7c_row3_col4" class="data row3 col4" >8</td>
#       <td id="T_0ea7c_row3_col5" class="data row3 col5" >$1.56 \times 10^{-5}$</td>
#       <td id="T_0ea7c_row3_col6" class="data row3 col6" >1</td>
#       <td id="T_0ea7c_row3_col7" class="data row3 col7" ></td>
#       <td id="T_0ea7c_row3_col8" class="data row3 col8" ></td>
#       <td id="T_0ea7c_row3_col9" class="data row3 col9" ></td>
#       <td id="T_0ea7c_row3_col10" class="data row3 col10" ></td>
#     </tr>
#     <tr>
#       <th id="T_0ea7c_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_0ea7c_row4_col0" class="data row4 col0" >KO_sgAB_R1_sense_yjl229</td>
#       <td id="T_0ea7c_row4_col1" class="data row4 col1" >$3.16 \times 10^{-1}$</td>
#       <td id="T_0ea7c_row4_col2" class="data row4 col2" >31</td>
#       <td id="T_0ea7c_row4_col3" class="data row4 col3" >$3.25 \times 10^{-4}$</td>
#       <td id="T_0ea7c_row4_col4" class="data row4 col4" >7</td>
#       <td id="T_0ea7c_row4_col5" class="data row4 col5" >$1.10 \times 10^{-5}$</td>
#       <td id="T_0ea7c_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_0ea7c_row4_col7" class="data row4 col7" >$1.15 \times 10^{-5}$</td>
#       <td id="T_0ea7c_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_0ea7c_row4_col9" class="data row4 col9" ></td>
#       <td id="T_0ea7c_row4_col10" class="data row4 col10" ></td>
#     </tr>
#     <tr>
#       <th id="T_0ea7c_level0_row5" class="row_heading level0 row5" >9</th>
#       <td id="T_0ea7c_row5_col0" class="data row5 col0" >KO_sgAB_R1_sense_yjl230</td>
#       <td id="T_0ea7c_row5_col1" class
# Experiments with large second component, at a lower threshold of 1e-6
# <style type="text/css">
# #T_79668_row0_col0, #T_79668_row1_col0, #T_79668_row2_col0, #T_79668_row3_col0, #T_79668_row4_col0, #T_79668_row5_col0, #T_79668_row6_col0, #T_79668_row7_col0, #T_79668_row8_col0, #T_79668_row9_col0, #T_79668_row10_col0, #T_79668_row11_col0, #T_79668_row12_col0, #T_79668_row13_col0, #T_79668_row14_col0, #T_79668_row15_col0, #T_79668_row16_col0 {
#   color: red;
# }
# #T_79668_row0_col2, #T_79668_row0_col4, #T_79668_row0_col6, #T_79668_row0_col8, #T_79668_row0_col10, #T_79668_row1_col2, #T_79668_row1_col4, #T_79668_row1_col6, #T_79668_row1_col8, #T_79668_row1_col10, #T_79668_row2_col2, #T_79668_row2_col4, #T_79668_row2_col6, #T_79668_row2_col8, #T_79668_row2_col10, #T_79668_row3_col2, #T_79668_row3_col4, #T_79668_row3_col6, #T_79668_row3_col8, #T_79668_row3_col10, #T_79668_row4_col2, #T_79668_row4_col4, #T_79668_row4_col6, #T_79668_row4_col8, #T_79668_row4_col10, #T_79668_row5_col2, #T_79668_row5_col4, #T_79668_row5_col6, #T_79668_row5_col8, #T_79668_row5_col10, #T_79668_row6_col2, #T_79668_row6_col4, #T_79668_row6_col6, #T_79668_row6_col8, #T_79668_row6_col10, #T_79668_row7_col2, #T_79668_row7_col4, #T_79668_row7_col6, #T_79668_row7_col8, #T_79668_row7_col10, #T_79668_row8_col2, #T_79668_row8_col4, #T_79668_row8_col6, #T_79668_row8_col8, #T_79668_row8_col10, #T_79668_row9_col2, #T_79668_row9_col4, #T_79668_row9_col6, #T_79668_row9_col8, #T_79668_row9_col10, #T_79668_row10_col2, #T_79668_row10_col4, #T_79668_row10_col6, #T_79668_row10_col8, #T_79668_row10_col10, #T_79668_row11_col2, #T_79668_row11_col4, #T_79668_row11_col6, #T_79668_row11_col8, #T_79668_row11_col10, #T_79668_row12_col2, #T_79668_row12_col4, #T_79668_row12_col6, #T_79668_row12_col8, #T_79668_row12_col10, #T_79668_row13_col2, #T_79668_row13_col4, #T_79668_row13_col6, #T_79668_row13_col8, #T_79668_row13_col10, #T_79668_row14_col2, #T_79668_row14_col4, #T_79668_row14_col6, #T_79668_row14_col8, #T_79668_row14_col10, #T_79668_row15_col2, #T_79668_row15_col4, #T_79668_row15_col6, #T_79668_row15_col8, #T_79668_row15_col10, #T_79668_row16_col2, #T_79668_row16_col4, #T_79668_row16_col6, #T_79668_row16_col8, #T_79668_row16_col10, #T_79668_row17_col2, #T_79668_row17_col4, #T_79668_row17_col6, #T_79668_row17_col8, #T_79668_row17_col10, #T_79668_row18_col2, #T_79668_row18_col4, #T_79668_row18_col6, #T_79668_row18_col8, #T_79668_row18_col10 {
#   color: gray;
# }
# #T_79668_row17_col0, #T_79668_row18_col0 {
#   color: orange;
# }
# </style>
# <table id="T_79668">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_79668_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_79668_level0_col1" class="col_heading level0 col1" >W₀</th>
#       <th id="T_79668_level0_col2" class="col_heading level0 col2" >C₀</th>
#       <th id="T_79668_level0_col3" class="col_heading level0 col3" >W₁</th>
#       <th id="T_79668_level0_col4" class="col_heading level0 col4" >C₁</th>
#       <th id="T_79668_level0_col5" class="col_heading level0 col5" >W₂</th>
#       <th id="T_79668_level0_col6" class="col_heading level0 col6" >C₂</th>
#       <th id="T_79668_level0_col7" class="col_heading level0 col7" >W₃</th>
#       <th id="T_79668_level0_col8" class="col_heading level0 col8" >C₃</th>
#       <th id="T_79668_level0_col9" class="col_heading level0 col9" >W₄</th>
#       <th id="T_79668_level0_col10" class="col_heading level0 col10" >C₄</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_79668_level0_row0" class="row_heading level0 row0" >3</th>
#       <td id="T_79668_row0_col0" class="data row0 col0" >KO_sgAB_R1_branch_yjl236</td>
#       <td id="T_79668_row0_col1" class="data row0 col1" >$1.29 \times 10^{-1}$</td>
#       <td id="T_79668_row0_col2" class="data row0 col2" >99</td>
#       <td id="T_79668_row0_col3" class="data row0 col3" >$3.26 \times 10^{-6}$</td>
#       <td id="T_79668_row0_col4" class="data row0 col4" >2</td>
#       <td id="T_79668_row0_col5" class="data row0 col5" >$1.04 \times 10^{-6}$</td>
#       <td id="T_79668_row0_col6" class="data row0 col6" >1</td>
#       <td id="T_79668_row0_col7" class="data row0 col7" >$1.04 \times 10^{-6}$</td>
#       <td id="T_79668_row0_col8" class="data row0 col8" >1</td>
#       <td id="T_79668_row0_col9" class="data row0 col9" >$1.19 \times 10^{-6}$</td>
#       <td id="T_79668_row0_col10" class="data row0 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_79668_level0_row1" class="row_heading level0 row1" >5</th>
#       <td id="T_79668_row1_col0" class="data row1 col0" >KO_sgAB_R1_cmv_yjl238</td>
#       <td id="T_79668_row1_col1" class="data row1 col1" >$3.49 \times 10^{-1}$</td>
#       <td id="T_79668_row1_col2" class="data row1 col2" >224</td>
#       <td id="T_79668_row1_col3" class="data row1 col3" >$5.27 \times 10^{-6}$</td>
#       <td id="T_79668_row1_col4" class="data row1 col4" >2</td>
#       <td id="T_79668_row1_col5" class="data row1 col5" >$1.02 \times 10^{-6}$</td>
#       <td id="T_79668_row1_col6" class="data row1 col6" >1</td>
#       <td id="T_79668_row1_col7" class="data row1 col7" >$1.02 \times 10^{-6}$</td>
#       <td id="T_79668_row1_col8" class="data row1 col8" >1</td>
#       <td id="T_79668_row1_col9" class="data row1 col9" >$1.02 \times 10^{-6}$</td>
#       <td id="T_79668_row1_col10" class="data row1 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_79668_level0_row2" class="row_heading level0 row2" >6</th>
#       <td id="T_79668_row2_col0" class="data row2 col0" >KO_sgAB_R1_cmv_yjl239</td>
#       <td id="T_79668_row2_col1" class="data row2 col1" >$3.40 \times 10^{-1}$</td>
#       <td id="T_79668_row2_col2" class="data row2 col2" >221</td>
#       <td id="T_79668_row2_col3" class="data row2 col3" >$3.31 \times 10^{-6}$</td>
#       <td id="T_79668_row2_col4" class="data row2 col4" >3</td>
#       <td id="T_79668_row2_col5" class="data row2 col5" >$4.38 \times 10^{-6}$</td>
#       <td id="T_79668_row2_col6" class="data row2 col6" >2</td>
#       <td id="T_79668_row2_col7" class="data row2 col7" >$4.58 \times 10^{-6}$</td>
#       <td id="T_79668_row2_col8" class="data row2 col8" >2</td>
#       <td id="T_79668_row2_col9" class="data row2 col9" >$1.17 \times 10^{-6}$</td>
#       <td id="T_79668_row2_col10" class="data row2 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_79668_level0_row3" class="row_heading level0 row3" >7</th>
#       <td id="T_79668_row3_col0" class="data row3 col0" >KO_sgAB_R1_cmv_yjl240</td>
#       <td id="T_79668_row3_col1" class="data row3 col1" >$3.17 \times 10^{-1}$</td>
#       <td id="T_79668_row3_col2" class="data row3 col2" >234</td>
#       <td id="T_79668_row3_col3" class="data row3 col3" >$8.61 \times 10^{-6}$</td>
#       <td id="T_79668_row3_col4" class="data row3 col4" >5</td>
#       <td id="T_79668_row3_col5" class="data row3 col5" >$7.44 \times 10^{-6}$</td>
#       <td id="T_79668_row3_col6" class="data row3 col6" >5</td>
#       <td id="T_79668_row3_col7" class="data row3 col7" >$1.06 \times 10^{-6}$</td>
#       <td id="T_79668_row3_col8" class="data row3 col8" >1</td>
#       <td id="T_79668_row3_col9" class="data row3 col9" >$1.06 \times 10^{-6}$</td>
#       <td id="T_79668_row3_col10" class="data row3 col10" >1</td>
#     </tr>
#     <tr>
#       <th id="T_79668_level0_row4" class="row_heading level0 row4" >8</th>
#       <td id="T_79668_row4_col0" class="data row4 col0" >KO_sgAB_R1_sense_yjl229</td>
#       <td id="T_79668_row4_col1" class="data row4 col1" >$3.17 \times 10^{-1}$</td>
#       <td id="T_79668_row4_col2" class="data row4 col2" >210</td>
#       <td id="T_79668_row4_col3" class="data row4 col3" >$2.74 \times 10^{-6}$</td>
#       <td id="T_79668_row4_col4" class="data row4 col4" >2</td>
#       <td id="T_79668_row4_col5" class="data row4 col5" >$1.06 \times 10^{-6}$</td>
#       <td id="T_79668_row4_col6" class="data row4 col6" >1</td>
#       <td id="T_79668_row4_col7" class="data row4 col7" >$1.15 \times 10^{-6}$</td>
#       <td id="T_79668_row4_col8" class="data row4 col8" >1</td>
#       <td id="T_79668_row4_col9" class="data row4 col9" >$1.15 \times 10^{-6}$</td>
#       <td id="T_79668_row4_col10" class="data row4 col10" >1

# %% [markdown]
# ### E. Understanding the Cycles
#
# We focus on the experiments that exhibit 1-dimensional cycles and compute, using SageMath, a representative cycle for each homology class. Because even a 1-dimensional cycle can randomly occur, we don't investigate this cases further unless the cycle still appears in the average experiment, which we analyze in the notebook `2_DNA_DSB_InDelsTopo_AvgAnalysis.ipynb`

# %%
from InDelsTopo import Chain, Block, Complex
Table1=Table[Table['β₁']>0].sort_values('Experiment')
Indices1=Table1.index
print('Experiments with 1-homology \n ------------------------------\n')
format_table(Table1)


#Now we look for the generators of the homology
print('Homolgy generators:\n ------------------------------\n')
for index in Indices1:
    K=Filtrations[index]
    CC,ordered_blocks=K.get_complex().get_chain_complex_sage(True)
    gens=CC.homology(generators=True)
    
    cycle_coeffs=gens[1][0][1].vector(1)
    
    cycle_chain = Chain('0', prod_symbol='')
    
    # Combine the 1-dimensional blocks with coefficients
    for c, blk in zip(cycle_coeffs, ordered_blocks[1]):
        cycle_chain += int(c) * blk  # convert Sage integers to Python int

    print(K.exp_name,':\n', cycle_chain)

#We study the result of adding the vertex GACG to the complexes
print('\nHomology after adding GACG\n ------------------------------\n')
for index in Indices1:
    K=Filtrations[index]
    K2=K.get_complex()
    V=K2[0]
    V=V+[Block('GACG', prod_symbol='')]
    K3=Complex()
    K3.compute_d_skeleton(V, already_blocks=True)
    print(K.exp_name, ':\n')
    print(K3.get_homology_sage())
# Out:
# Experiments with 1-homology
#  ------------------------------
# <style type="text/css">
# #T_9cea0_row0_col0, #T_9cea0_row1_col0, #T_9cea0_row3_col0, #T_9cea0_row4_col0, #T_9cea0_row5_col0, #T_9cea0_row6_col0, #T_9cea0_row7_col0, #T_9cea0_row8_col0, #T_9cea0_row9_col0 {
#   color: red;
# }
# #T_9cea0_row2_col0, #T_9cea0_row10_col0 {
#   color: green;
# }
# #T_9cea0_row11_col0 {
#   color: orange;
# }
# </style>
# <table id="T_9cea0">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_9cea0_level0_col0" class="col_heading level0 col0" >Experiment</th>
#       <th id="T_9cea0_level0_col1" class="col_heading level0 col1" >Dimension</th>
#       <th id="T_9cea0_level0_col2" class="col_heading level0 col2" >β₀</th>
#       <th id="T_9cea0_level0_col3" class="col_heading level0 col3" >β₁</th>
#       <th id="T_9cea0_level0_col4" class="col_heading level0 col4" >β₂</th>
#       <th id="T_9cea0_level0_col5" class="col_heading level0 col5" >β₃</th>
#       <th id="T_9cea0_level0_col6" class="col_heading level0 col6" >β₄</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_9cea0_level0_row0" class="row_heading level0 row0" >4</th>
#       <td id="T_9cea0_row0_col0" class="data row0 col0" >KO_sgAB_R1_cmv_yjl237</td>
#       <td id="T_9cea0_row0_col1" class="data row0 col1" >3</td>
#       <td id="T_9cea0_row0_col2" class="data row0 col2" >3</td>
#       <td id="T_9cea0_row0_col3" class="data row0 col3" >1</td>
#       <td id="T_9cea0_row0_col4" class="data row0 col4" ></td>
#       <td id="T_9cea0_row0_col5" class="data row0 col5" ></td>
#       <td id="T_9cea0_row0_col6" class="data row0 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row1" class="row_heading level0 row1" >7</th>
#       <td id="T_9cea0_row1_col0" class="data row1 col0" >KO_sgAB_R1_cmv_yjl240</td>
#       <td id="T_9cea0_row1_col1" class="data row1 col1" >3</td>
#       <td id="T_9cea0_row1_col2" class="data row1 col2" >3</td>
#       <td id="T_9cea0_row1_col3" class="data row1 col3" >1</td>
#       <td id="T_9cea0_row1_col4" class="data row1 col4" ></td>
#       <td id="T_9cea0_row1_col5" class="data row1 col5" ></td>
#       <td id="T_9cea0_row1_col6" class="data row1 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row2" class="row_heading level0 row2" >29</th>
#       <td id="T_9cea0_row2_col0" class="data row2 col0" >KO_sgA_R1_cmv_yjl301</td>
#       <td id="T_9cea0_row2_col1" class="data row2 col1" >3</td>
#       <td id="T_9cea0_row2_col2" class="data row2 col2" >2</td>
#       <td id="T_9cea0_row2_col3" class="data row2 col3" >1</td>
#       <td id="T_9cea0_row2_col4" class="data row2 col4" ></td>
#       <td id="T_9cea0_row2_col5" class="data row2 col5" ></td>
#       <td id="T_9cea0_row2_col6" class="data row2 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row3" class="row_heading level0 row3" >48</th>
#       <td id="T_9cea0_row3_col0" class="data row3 col0" >WT_sgAB_R1_branch_yjl221</td>
#       <td id="T_9cea0_row3_col1" class="data row3 col1" >3</td>
#       <td id="T_9cea0_row3_col2" class="data row3 col2" >2</td>
#       <td id="T_9cea0_row3_col3" class="data row3 col3" >1</td>
#       <td id="T_9cea0_row3_col4" class="data row3 col4" ></td>
#       <td id="T_9cea0_row3_col5" class="data row3 col5" ></td>
#       <td id="T_9cea0_row3_col6" class="data row3 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row4" class="row_heading level0 row4" >52</th>
#       <td id="T_9cea0_row4_col0" class="data row4 col0" >WT_sgAB_R1_cmv_yjl225</td>
#       <td id="T_9cea0_row4_col1" class="data row4 col1" >3</td>
#       <td id="T_9cea0_row4_col2" class="data row4 col2" >5</td>
#       <td id="T_9cea0_row4_col3" class="data row4 col3" >1</td>
#       <td id="T_9cea0_row4_col4" class="data row4 col4" ></td>
#       <td id="T_9cea0_row4_col5" class="data row4 col5" ></td>
#       <td id="T_9cea0_row4_col6" class="data row4 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row5" class="row_heading level0 row5" >53</th>
#       <td id="T_9cea0_row5_col0" class="data row5 col0" >WT_sgAB_R1_cmv_yjl226</td>
#       <td id="T_9cea0_row5_col1" class="data row5 col1" >3</td>
#       <td id="T_9cea0_row5_col2" class="data row5 col2" >5</td>
#       <td id="T_9cea0_row5_col3" class="data row5 col3" >1</td>
#       <td id="T_9cea0_row5_col4" class="data row5 col4" ></td>
#       <td id="T_9cea0_row5_col5" class="data row5 col5" ></td>
#       <td id="T_9cea0_row5_col6" class="data row5 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row6" class="row_heading level0 row6" >54</th>
#       <td id="T_9cea0_row6_col0" class="data row6 col0" >WT_sgAB_R1_cmv_yjl227</td>
#       <td id="T_9cea0_row6_col1" class="data row6 col1" >3</td>
#       <td id="T_9cea0_row6_col2" class="data row6 col2" >6</td>
#       <td id="T_9cea0_row6_col3" class="data row6 col3" >1</td>
#       <td id="T_9cea0_row6_col4" class="data row6 col4" ></td>
#       <td id="T_9cea0_row6_col5" class="data row6 col5" ></td>
#       <td id="T_9cea0_row6_col6" class="data row6 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row7" class="row_heading level0 row7" >55</th>
#       <td id="T_9cea0_row7_col0" class="data row7 col0" >WT_sgAB_R1_cmv_yjl228</td>
#       <td id="T_9cea0_row7_col1" class="data row7 col1" >3</td>
#       <td id="T_9cea0_row7_col2" class="data row7 col2" >6</td>
#       <td id="T_9cea0_row7_col3" class="data row7 col3" >1</td>
#       <td id="T_9cea0_row7_col4" class="data row7 col4" ></td>
#       <td id="T_9cea0_row7_col5" class="data row7 col5" ></td>
#       <td id="T_9cea0_row7_col6" class="data row7 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row8" class="row_heading level0 row8" >57</th>
#       <td id="T_9cea0_row8_col0" class="data row8 col0" >WT_sgAB_R1_sense_yjl218</td>
#       <td id="T_9cea0_row8_col1" class="data row8 col1" >3</td>
#       <td id="T_9cea0_row8_col2" class="data row8 col2" >5</td>
#       <td id="T_9cea0_row8_col3" class="data row8 col3" >1</td>
#       <td id="T_9cea0_row8_col4" class="data row8 col4" ></td>
#       <td id="T_9cea0_row8_col5" class="data row8 col5" ></td>
#       <td id="T_9cea0_row8_col6" class="data row8 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row9" class="row_heading level0 row9" >59</th>
#       <td id="T_9cea0_row9_col0" class="data row9 col0" >WT_sgAB_R1_sense_yjl220</td>
#       <td id="T_9cea0_row9_col1" class="data row9 col1" >3</td>
#       <td id="T_9cea0_row9_col2" class="data row9 col2" >3</td>
#       <td id="T_9cea0_row9_col3" class="data row9 col3" >1</td>
#       <td id="T_9cea0_row9_col4" class="data row9 col4" ></td>
#       <td id="T_9cea0_row9_col5" class="data row9 col5" ></td>
#       <td id="T_9cea0_row9_col6" class="data row9 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row10" class="row_heading level0 row10" >76</th>
#       <td id="T_9cea0_row10_col0" class="data row10 col0" >WT_sgA_R1_cmv_yjl263</td>
#       <td id="T_9cea0_row10_col1" class="data row10 col1" >4</td>
#       <td id="T_9cea0_row10_col2" class="data row10 col2" >1</td>
#       <td id="T_9cea0_row10_col3" class="data row10 col3" >1</td>
#       <td id="T_9cea0_row10_col4" class="data row10 col4" ></td>
#       <td id="T_9cea0_row10_col5" class="data row10 col5" ></td>
#       <td id="T_9cea0_row10_col6" class="data row10 col6" ></td>
#     </tr>
#     <tr>
#       <th id="T_9cea0_level0_row11" class="row_heading level0 row11" >105</th>
#       <td id="T_9cea0_row11_col0" class="data row11 col0" >WT_sgCD_R2_antisense_yjl090n350</td>
#       <td id="T_9cea0_row11_col1" class="data row11 col1" >3</td>
#       <td id="T_9cea0_row11_col2" class="data row11 col2" >4</td>
#       <td id="T_9cea0_row11_col3" class="data row11 col3" >1</td>
#       <td id="T_9cea0_row11_col4" class="data row11 col4" ></td>
#       <td id="T_9cea0_row11_col5" class="data row11 col5" ></td>
#       <td id="T_9cea0_row11_col6" class="data row11 col6" ></td>
#     </tr>
#   </tbody>
# </table>
# Homolgy generators:
#  ------------------------------
#
# KO_sgAB_R1_cmv_yjl237 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# KO_sgAB_R1_cmv_yjl240 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# KO_sgA_R1_cmv_yjl301 :
#  T^2(1,A)TA^2 + T^2(1,T)A^2 - T^2A(1,T)A - T^2ATA(1,A)
# WT_sgAB_R1_branch_yjl221 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# WT_sgAB_R1_cmv_yjl225 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# WT_sgAB_R1_cmv_yjl226 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# WT_sgAB_R1_cmv_yjl227 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# WT_sgAB_R1_cmv_yjl228 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# WT_sgAB_R1_sense_yjl218 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# WT_sgAB_R1_sense_yjl220 :
#  GACG(1,A)T + GACG(1,T)A - GACGA(1,T) - GACGT(1,A)
# WT_sgA_R1_cmv_yjl263 :
#  T(1,G) - T(1,T) + T(1,T)GCA + TG(1,A) + TG(1,C)A - T^2(1,T) + T^2(1,T)GCA - T^3(1,G)A - T^3(1,T) + T^3(1,T)A^2 + T^3A(1,T) - T^3A(1,T)A + T^3AT(1,A) - T^3G(1,C)A - T^4(1,T) + T^4(1,T)A - T^4A(1,A) - T^5(1,A)
# WT_sgCD_R2_antisense_yjl090n350 :
#  -(1,T)CT + (1,T)C^2 + C(1,C) - C(1,T) + T(1,C)T + T(1,G)CA + T(1,T)G - TC(1,C)A + TC^2(1,A) - TG(1,C)A - TG(1,G) + TG(1,G)A - TG^2(1,A) - T^2(1,G)
#
# Homology after adding GACG
#  ------------------------------
#
# KO_sgAB_R1_cmv_yjl237 :
#
# {-1: 0, 0: Z x Z, 1: 0, 2: 0, 3: 0}
# KO_sgAB_R1_cmv_yjl240 :
#
# {-1: 0, 0: Z x Z, 1: 0, 2: 0, 3: 0}
# KO_sgA_R1_cmv_yjl301 :
#
# {-1: 0, 0: Z x Z, 1: Z, 2: 0, 3: 0}
# WT_sgAB_R1_branch_yjl221 :
#
# {-1: 0, 0: Z, 1: 0, 2: 0, 3: 0}
# WT_sgAB_R1_cmv_yjl225 :
#
# {-1: 0, 0: Z x Z x Z x Z, 1: 0, 2: 0, 3: 0}
# WT_sgAB_R1_cmv_yjl226 :
#
# {-1: 0, 0: Z x Z x Z x Z, 1: 0, 2: 0, 3: 0}
# WT_sgAB_R1_cmv_yjl227 :
#
# {-1: 0, 0: Z^5, 1: 0, 2: 0, 3: 0}
# WT_sgAB_R1_cmv_yjl228 :
#
# {-1: 0, 0: Z^5, 1: 0, 2: 0, 3: 0}
# WT_sgAB_R1_sense_yjl218 :
#
# {-1: 0, 0: Z x Z x Z x Z, 1: 0, 2: 0, 3: 0}
# WT_sgAB_R1_sense_yjl220 :
#
# {-1: 0, 0: Z x Z, 1: 0, 2: 0, 3: 0}
# WT_sgA_R1_cmv_yjl263 :
#
# {-1: 0, 0: Z, 1: Z, 2: 0, 3: 0, 4: 0}
# WT_sgCD_R2_antisense_yjl090n350 :
#
# {-1: 0, 0: Z x Z x Z x Z, 1: Z, 2: 0, 3: 0}

# %% [markdown]
# ### E. Understanding the Cycles
#
# We focus on the experiments that exhibit 1-dimensional cycles and compute, using SageMath, a representative cycle for each homology class.
#
# In all three cases, the cycle has length 4 and is spanned by the vertices:
#
# $$GACGA, \; GACGAT, \; GACGT, \; GACGTA.$$
#
# Notably, if we add the fifth vertex $GACG$, the cycle disappears. Computing the homology of the complexes after including this vertex confirms that it alone is sufficient to eliminate all higher-dimensional ($\geq 1$) homology.

# %% [markdown]
# ### F. Check Frequencies
#
# For the few experiments in which we observe 1-dimensional homology, the addition of the sequence `'GACG'` eliminates the cycle. We therefore report the average frequencies of the vertices in the generating cycle, as well as the frequency of this particular sequence.
#
# We observe that `'GACG'` does appear in the experiments, but at an order of magnitude lower frequency than the other vertices, despite being one nucleotide shorter, which would normally make it more likely. This suggests that there may be some bias or structural factor influencing the formation of these cycles, which appear only in experiments at location AB.

# %%
vertices=['GACGA', 'GACGAT', 'GACGT', 'GACGTA','GACG' ]
for index in Indices1:
    Experiment=Average_Experiments[index]
    Table=Experiment['table']
    Table=Table[Table.sequence.isin(vertices)]
    print(Experiment['exp_name'])
    display(Table)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/cc/5ptmjf196ng6twj_97hb7mfc0000gn/T/ipykernel_75740/1519516991.py in <module>
#       1 vertices=['GACGA', 'GACGAT', 'GACGT', 'GACGTA','GACG' ]
#       2 for index in Indices1:
# ----> 3     Experiment=Average_Experiments[index]
#       4     Table=Experiment['table']
#       5     Table=Table[Table.sequence.isin(vertices)]
#
# NameError: name 'Average_Experiments' is not defined
