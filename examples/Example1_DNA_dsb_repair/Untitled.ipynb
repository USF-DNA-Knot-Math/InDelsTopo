# %%
1+1
# Out:
# 2

# %%
expand((x+1)*(x-1))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 expand((x+1)*(x-1))
#
# NameError: name 'expand' is not defined
