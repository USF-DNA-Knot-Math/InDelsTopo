# %%
expand((x+1)*(x-1))
# Out:
# x^2 - 1

# %%
Graph([[1,2,3],[[1,2],[2,3]]])
# Out:
# Matplotlib is building the font cache; this may take a moment.
# Graph on 3 vertices

# %%
# %matplotlib ipympl
import matplotlib.pyplot as plt
import numpy as np

fig, ax = plt.subplots()


x = np.linspace(0, 2*np.pi, 100)
y = np.sin(3*x)
ax.plot(x, y)
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# File /opt/miniconda3/envs/InDelsTopo_env/lib/python3.10/site-packages/matplotlib/backends/registry.py:407, in BackendRegistry.resolve_gui_or_backend(self, gui_or_backend)
#     406 try:
# --> 407     return self.resolve_backend(gui_or_backend)
#     408 except Exception:  # KeyError ?
#
# File /opt/miniconda3/envs/InDelsTopo_env/lib/python3.10/site-packages/matplotlib/backends/registry.py:369, in BackendRegistry.resolve_backend(self, backend)
#     368 if gui is None:
# --> 369     raise RuntimeError(f"'{backend}' is not a recognised backend name")
#     371 return backend, gui if gui != "headless" else None
#
# RuntimeError: 'ipympl' is not a recognised backend name
#
# During handling of the above exception, another exception occurred:
#
# RuntimeError                              Traceback (most recent call last)
# ...
